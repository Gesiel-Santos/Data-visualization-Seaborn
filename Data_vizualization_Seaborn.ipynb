# %% [markdown]
# <a href="https://colab.research.google.com/github/Gesiel30/Data-vizualization-Seaborn/blob/main/Data_vizualization_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando Base de dados

# %%
import pandas as pd
dados = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Visualizaçao/tips.csv')
dados
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %% [markdown]
# # Tradução

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill': 'valor_da_conta',
    'tip': 'gorjeta',
    'dessert': 'sobremesa',
    'day': 'dia_semana',
    'time': 'hora_do_dia',
    'size': 'total_de_pessoas'
}

# %%
renomear
# Out:
# {'total_bill': 'valor_da_conta',
#  'tip': 'gorjeta',
#  'dessert': 'sobremesa',
#  'day': 'dia_semana',
#  'time': 'hora_do_dia',
#  'size': 'total_de_pessoas'}

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
gorjetas = dados.rename(columns=renomear)
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_semana hora_do_dia  \
# 0             16.99     1.01        No        Sun      Dinner
# 1             10.34     1.66        No        Sun      Dinner
# 2             21.01     3.50        No        Sun      Dinner
# 3             23.68     3.31        No        Sun      Dinner
# 4             24.59     3.61        No        Sun      Dinner
# ..              ...      ...       ...        ...         ...
# 239           29.03     5.92        No        Sat      Dinner
# 240           27.18     2.00       Yes        Sat      Dinner
# 241           22.67     2.00       Yes        Sat      Dinner
# 242           17.82     1.75        No        Sat      Dinner
# 243           18.78     3.00        No       Thur      Dinner
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# 239                 3
# 240                 2
# ...

# %%
gorjetas.sobremesa.unique() # Retornar valores exclusivos dentro do que estou procurando
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {'No': 'Não',
           'Yes': 'Sim'}

# %%
gorjetas.sobremesa.map(sim_nao).head(25)
# Out:
# 0     Não
# 1     Não
# 2     Não
# 3     Não
# 4     Não
# 5     Não
# 6     Não
# 7     Não
# 8     Não
# 9     Não
# 10    Não
# 11    Não
# 12    Não
# 13    Não
# 14    Não
# 15    Não
# 16    Não
# 17    Não
# 18    Não
# 19    Não
# 20    Não
# 21    Não
# 22    Não
# 23    Não
# 24    Não
# Name: sobremesa, dtype: object

# %%
gorjetas.sobremesa# ainda nao aterou meus dados internos
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#       ...
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: sobremesa, Length: 244, dtype: object

# %%
# vamos atribuir esse mapa para nossa variavel gorjeta
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
# agora variavel gorjeta, foi alterada seus dados internos
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_semana hora_do_dia  total_de_pessoas
# 0           16.99     1.01       Não        Sun      Dinner                 2
# 1           10.34     1.66       Não        Sun      Dinner                 3
# 2           21.01     3.50       Não        Sun      Dinner                 3
# 3           23.68     3.31       Não        Sun      Dinner                 2
# 4           24.59     3.61       Não        Sun      Dinner                 4

# %% [markdown]
# ## Agora para os dias da semana

# %%
gorjetas.dia_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {'Sun': 'Domingo',
        'Sat': 'Sabado',
        'Thur': 'Quinta',
        'Fri': 'Sexta'

}

# %%
gorjetas.dia_semana = gorjetas.dia_semana.map(dias)

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_semana hora_do_dia  \
# 0             16.99     1.01       Não    Domingo      Dinner
# 1             10.34     1.66       Não    Domingo      Dinner
# 2             21.01     3.50       Não    Domingo      Dinner
# 3             23.68     3.31       Não    Domingo      Dinner
# 4             24.59     3.61       Não    Domingo      Dinner
# ..              ...      ...       ...        ...         ...
# 239           29.03     5.92       Não     Sabado      Dinner
# 240           27.18     2.00       Sim     Sabado      Dinner
# 241           22.67     2.00       Sim     Sabado      Dinner
# 242           17.82     1.75       Não     Sabado      Dinner
# 243           18.78     3.00       Não     Quinta      Dinner
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# 239                 3
# 240                 2
# ...

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {'Dinner': 'Jantar',
        'Lunch':'Almoço'

}

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(hora)
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_semana hora_do_dia  \
# 0             16.99     1.01       Não    Domingo      Jantar
# 1             10.34     1.66       Não    Domingo      Jantar
# 2             21.01     3.50       Não    Domingo      Jantar
# 3             23.68     3.31       Não    Domingo      Jantar
# 4             24.59     3.61       Não    Domingo      Jantar
# ..              ...      ...       ...        ...         ...
# 239           29.03     5.92       Não     Sabado      Jantar
# 240           27.18     2.00       Sim     Sabado      Jantar
# 241           22.67     2.00       Sim     Sabado      Jantar
# 242           17.82     1.75       Não     Sabado      Jantar
# 243           18.78     3.00       Não     Quinta      Jantar
#
#      total_de_pessoas
# 0                   2
# 1                   3
# 2                   3
# 3                   2
# 4                   4
# ..                ...
# 239                 3
# 240                 2
# ...

# %% [markdown]
# # Traduçao automatica mais pode gerar erros tbm

# %%
pip install googletrans==4.0.0-rc1 # utilizo esse algotitmo
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 26.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 8.2 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=2c456ce65f87dc5c4c91c558a5c551bce8ea3ca76572631bcca8e101319b8126
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
# Importando 'Translator()' e atribuindo a 'tradutor':
from googletrans import Translator
tradutor = Translator()

# Recuperando o nome das colunas do df e convertendo em lista:
colunas_ingles = list(gorjetas.hora_do_dia)

 # Tirando o '_' para que a tradução ocorra sem problemas:
colunas_ingles_para_traducao = []
for i in colunas_ingles:
    colunas_ingles_para_traducao.append(i.replace('_', ' '))

# Traduzindo:
colunas_portugues_traduzida = []
for i in colunas_ingles_para_traducao:
    colunas_portugues_traduzida.append(tradutor.translate(i, dest = "pt").text)

# Colocando '_' novamente nas strings:
colunas_portugues = []
for i in colunas_portugues_traduzida:
     colunas_portugues.append(i.replace(' ', '_'))

# Criando dicionário para aplicação do 'rename':
renomeacao = dict(zip(colunas_ingles, colunas_portugues))

# Renomeando:
dados.rename(columns = renomeacao, inplace = False)
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %% [markdown]
# # Importando o Seborn ele e feito para data frame

# %%
import seaborn as sns

# %%
# !pip show seaborn # version
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy, pandas
# Required-by: lida, missingno

# %% [markdown]
# # Analize I valor da conta e gorjeta

# %% [markdown]
# ## Visualmente o valor da gorjeta aumenta conforme valor da conta aumenta

# %%
ax = sns.scatterplot(data=gorjetas, x='valor_da_conta', y='gorjeta',
                     s=100)
ax.figure.set_size_inches(12, 6)

# %%
print('A base de dados contém {} registros \n'.format(gorjetas.shape[0]))
print('Registros não nulos')
gorjetas.count()
# Out:
# A base de dados contém 244 registros
#
# Registros não nulos
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_semana          244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# # Criando o campo porcentagem

# %%
gorjetas['porcentagem'] = gorjetas['gorjeta'] / gorjetas['valor_da_conta'] *100

# %%
gorjetas.porcentagem = gorjetas.porcentagem.round(2)
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_semana hora_do_dia  \
# 0             16.99     1.01       Não    Domingo      Jantar
# 1             10.34     1.66       Não    Domingo      Jantar
# 2             21.01     3.50       Não    Domingo      Jantar
# 3             23.68     3.31       Não    Domingo      Jantar
# 4             24.59     3.61       Não    Domingo      Jantar
# ..              ...      ...       ...        ...         ...
# 239           29.03     5.92       Não     Sabado      Jantar
# 240           27.18     2.00       Sim     Sabado      Jantar
# 241           22.67     2.00       Sim     Sabado      Jantar
# 242           17.82     1.75       Não     Sabado      Jantar
# 243           18.78     3.00       Não     Quinta      Jantar
#
#      total_de_pessoas  porcentagem
# 0                   2         5.94
# 1                   3        16.05
# 2                   3        16.66
# 3                   2        13.98
# 4                   4        14.68
# ...

# %%
ax = sns.scatterplot(data=gorjetas, x='valor_da_conta', y='porcentagem', s=100)

ax.figure.set_size_inches(12, 6)
# VISUALEMENTE O VALOR DA CONTA NAO E PROPORCIONALO AO VALOR DA GORJETA

# %%
ax = sns.relplot(x='valor_da_conta', y= 'porcentagem', kind='line', data=gorjetas)
ax.figure.set_size_inches(12, 6)

# %%
ax = sns.lmplot(x='valor_da_conta', y='porcentagem', data=gorjetas)
ax.figure.set_size_inches(12, 6)

# %% [markdown]
# ## Visualmente a distribuição apresenta pouca diferença

# %% [markdown]
# # Analize II sobremesa

# %%
gorjetas[gorjetas.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602    16.319140
# std          9.832154   1.401468          0.810751     8.511748
# min          3.070000   1.000000          1.000000     3.560000
# 25%         13.420000   2.000000          2.000000    10.680000
# 50%         17.920000   3.000000          2.000000    15.380000
# 75%         26.860000   3.680000          3.000000    19.510000
# max         50.810000  10.000000          5.000000    71.030000

# %%
gorjetas[gorjetas.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874    15.932318
# std          8.255582    1.377190          1.017984     3.990701
# min          7.250000    1.000000          1.000000     5.680000
# 25%         13.325000    2.000000          2.000000    13.690000
# 50%         17.590000    2.740000          2.000000    15.560000
# 75%         22.755000    3.505000          3.000000    18.500000
# max         48.330000    9.000000          6.000000    29.200000

# %%
sns.catplot(x='sobremesa', y= 'gorjeta', data=gorjetas)
ax.figure.set_size_inches(12, 6)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas)
ax.figure.set_size_inches(12, 15)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas, col='sobremesa')
ax.figure.set_size_inches(12, 15)

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas, col='sobremesa')
ax.figure.set_size_inches(12, 15)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', hue='sobremesa', data=gorjetas, col='sobremesa')
ax.figure.set_size_inches(12, 15)

# %% [markdown]
# ## Visualmente existe diferença daqueles que pediram sobremesa e nao pediram

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas, col='sobremesa', kind='line')
ax.figure.set_size_inches(12, 15)

# %% [markdown]
# # Teste de Hipotese

# %% [markdown]
# ##H<sup>null</sup>**
# **A distribuição da taxa da gorjeta é a mesma nos dois grupos **
#
# ##H<sup>alt</sup>**
# **A distribuição da taxa da gorjeta  não é a mesma nos dois grupos **

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query("sobremesa == 'Sim'").porcentagem

# %%
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem

# %%
ranksums(sobremesa, sem_sobremesa)
# Out:
# RanksumsResult(statistic=-0.5845504113520769, pvalue=0.558850059321255)

# %%
r = ranksums(sobremesa, sem_sobremesa)
print('O valor do p-value é {}'.format(r.pvalue))  # Rejeitamos a hipotese alternativa
# Out:
# O valor do p-value é 0.558850059321255

# %% [markdown]
# # Analise III dia da semana

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_semana hora_do_dia  \
# 0             16.99     1.01       Não    Domingo      Jantar
# 1             10.34     1.66       Não    Domingo      Jantar
# 2             21.01     3.50       Não    Domingo      Jantar
# 3             23.68     3.31       Não    Domingo      Jantar
# 4             24.59     3.61       Não    Domingo      Jantar
# ..              ...      ...       ...        ...         ...
# 239           29.03     5.92       Não     Sabado      Jantar
# 240           27.18     2.00       Sim     Sabado      Jantar
# 241           22.67     2.00       Sim     Sabado      Jantar
# 242           17.82     1.75       Não     Sabado      Jantar
# 243           18.78     3.00       Não     Quinta      Jantar
#
#      total_de_pessoas  porcentagem
# 0                   2         5.94
# 1                   3        16.05
# 2                   3        16.66
# 3                   2        13.98
# 4                   4        14.68
# ...

# %%
gorjetas.dia_semana.unique()
# Out:
# array(['Domingo', 'Sabado', 'Quinta', 'Sexta'], dtype=object)

# %%
ax = sns.catplot(x='dia_semana', y='valor_da_conta', data=gorjetas)
ax.figure.set_size_inches(12, 6)

# %%
ax = sns.relplot(x= 'valor_da_conta', y='gorjeta', data=gorjetas, hue='dia_semana')
ax.figure.set_size_inches(12, 6)

# %%
ax = sns.relplot(x= 'valor_da_conta', y='porcentagem', data=gorjetas, hue='dia_semana')
ax.figure.set_size_inches(12, 6)

# %%
ax = sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_semana', col='dia_semana', data=gorjetas)
ax.figure.set_size_inches(12, 6)

# %%
ax = sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_semana', col='dia_semana', data=gorjetas)
ax.figure.set_size_inches(12, 6)

# %%
ax = sns.lmplot(x='valor_da_conta', y='porcentagem', hue='dia_semana', col='dia_semana', data=gorjetas)
ax.figure.set_size_inches(12, 6)

# %%
media_geral_gorjetas = gorjetas.gorjeta.mean()
print('A média geral das gorjetas é de {}'.format(media_geral_gorjetas))
# Out:
# A média geral das gorjetas é de 2.99827868852459

# %%
gorjetas.groupby([gorjetas.dia_semana]).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
# <ipython-input-61-a3ebc53997d2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gorjetas.groupby([gorjetas.dia_semana]).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
#             valor_da_conta   gorjeta  porcentagem
# dia_semana
# Domingo          21.410000  3.255132    16.689605
# Quinta           17.682742  2.771452    16.126452
# Sabado           20.441379  2.993103    15.314598
# Sexta            17.151579  2.734737    16.991579

# %%
# ou tbm caso meu data frame tenha muitas colunas
gorjetas = gorjetas.drop(columns=['total_de_pessoas'])
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_semana hora_do_dia  porcentagem
# 0           16.99     1.01       Não    Domingo      Jantar         5.94
# 1           10.34     1.66       Não    Domingo      Jantar        16.05
# 2           21.01     3.50       Não    Domingo      Jantar        16.66
# 3           23.68     3.31       Não    Domingo      Jantar        13.98
# 4           24.59     3.61       Não    Domingo      Jantar        14.68

# %%
gorjetas.groupby([gorjetas.dia_semana]).mean()
# Out:
# <ipython-input-63-3d03b7d97350>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gorjetas.groupby([gorjetas.dia_semana]).mean()
#             valor_da_conta   gorjeta  porcentagem
# dia_semana
# Domingo          21.410000  3.255132    16.689605
# Quinta           17.682742  2.771452    16.126452
# Sabado           20.441379  2.993103    15.314598
# Sexta            17.151579  2.734737    16.991579

# %% [markdown]
# # Teste de Hipotese

# %% [markdown]
# ##H<sup>null</sup>**
# **A distribuição do valor da conta é a mesma no sabado e domingo **
#
# ##H<sup>alt</sup>**
# **A distribuição do valor da conta é a mesma no sabado e domingo **

# %%
valor_conta_domingo = gorjetas.query('dia_semana == "Domingo"').valor_da_conta
valor_conta_domingo
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 186    20.90
# 187    30.46
# 188    18.15
# 189    23.10
# 190    15.69
# Name: valor_da_conta, Length: 76, dtype: float64

# %%
valor_conta_sabado = gorjetas.query('dia_semana == "Sabado"').valor_da_conta
valor_conta_sabado
# Out:
# 19     20.65
# 20     17.92
# 21     20.29
# 22     15.77
# 23     39.42
#        ...
# 238    35.83
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# Name: valor_da_conta, Length: 87, dtype: float64

# %%
ranksums(valor_conta_domingo,valor_conta_sabado )
# p_valor maior q 0.5 n rejeitamos hipotese nula
# *A distribuição do valor da conta é a mesma no sabado e domingo *
# Out:
# RanksumsResult(statistic=0.9198084864360142, pvalue=0.3576728477868443)

# %% [markdown]
# # Analize IV Hora do dia

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_semana hora_do_dia  porcentagem
# 0             16.99     1.01       Não    Domingo      Jantar         5.94
# 1             10.34     1.66       Não    Domingo      Jantar        16.05
# 2             21.01     3.50       Não    Domingo      Jantar        16.66
# 3             23.68     3.31       Não    Domingo      Jantar        13.98
# 4             24.59     3.61       Não    Domingo      Jantar        14.68
# ..              ...      ...       ...        ...         ...          ...
# 239           29.03     5.92       Não     Sabado      Jantar        20.39
# 240           27.18     2.00       Sim     Sabado      Jantar         7.36
# 241           22.67     2.00       Sim     Sabado      Jantar         8.82
# 242           17.82     1.75       Não     Sabado      Jantar         9.82
# 243           18.78     3.00       Não     Quinta      Jantar        15.97
#
# [244 rows x 6 columns]

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas, kind='swarm') # metodo sward organiza os pontos,

# %%
sns.violinplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)
# Out:
# <Axes: xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoco = gorjetas.query('hora_do_dia == "Almoço"').valor_da_conta
jantar = gorjetas.query('hora_do_dia == "Jantar"').valor_da_conta

# %%
sns.histplot(almoco, kde=False)
# Out:
# <Axes: xlabel='valor_da_conta', ylabel='Count'>

# %%
sns.histplot(jantar, kde=False)
# Out:
# <Axes: xlabel='valor_da_conta', ylabel='Count'>

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
# <ipython-input-74-f114a0c0b279>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088    16.411765
# Jantar            20.797159  3.102670    15.951477

# %% [markdown]
# # Teste de Hipotese

# %% [markdown]
# Hnull**
# *A distribuição do valor da conta é a mesma no jantar e almoço *
#
# Halt**
# *A distribuição do valor da conta  não é igual no jantar e almoço *

# %%
ranksums(jantar, almoco)
# meu p_valor e menor q 0.05, entao aceitamos a hipotese alternativa, descartamos a hipotese nula
# Out:
# RanksumsResult(statistic=3.2438872807262955, pvalue=0.0011791039723641672)

# %% [markdown]
# # Relaçao da hora do dia pela porcentagem, fassos teste de hipotese

# %%
porcentagem_almoco = gorjetas.query("hora_do_dia == 'Almoço'").porcentagem

# %%
porcentagem_jantar = gorjetas.query("hora_do_dia == 'Jantar'").porcentagem

# %%
ranksums(porcentagem_almoco, porcentagem_jantar)
# Hnull** *A distribuição da taxa  da conta é a mesma no jantar e almoço *
# aceito hipotese nula, rejeito alternativa, pois p_value e maior, que 0.05
# Out:
# RanksumsResult(statistic=1.204699018193021, pvalue=0.22831951519679017)
